# %% [markdown]
# <h1>Modelo para inferir nota de determinado filme no IMDB</h1>
# Olá, me chamo <b>Karine</b> e neste projeto da <i>Sprint Programaria</i>, utilizamos um <a href='https://www.kaggle.com/carolzhangdc/imdb-5000-movie-dataset'> dataset público</a>: realizamos o tratamento dos dados, análise exploratória, criação e treinamento do modelo, e avaliação dos resultados. O objetivo é criar um modelo que prevê a nota de determinado filme no IMDB.

# %% [markdown]
# <h1>Import das bibliotecas</h1>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from plotnine import *

# %%
#Carregando o dataset utilizado
df = pd.read_csv('movie_metadata.csv')

# %%
#visualização
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
#verificando o tamanho do dataset (colunas e linhas)
df.shape
# Out:
# (5043, 28)

# %%
#tipo de dados encontrados nas colunas
df.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# ...

# %%
#colunas presentes no dataframe
list(df.columns)
# Out:
# ['color',
#  'director_name',
#  'num_critic_for_reviews',
#  'duration',
#  'director_facebook_likes',
#  'actor_3_facebook_likes',
#  'actor_2_name',
#  'actor_1_facebook_likes',
#  'gross',
#  'genres',
#  'actor_1_name',
#  'movie_title',
#  'num_voted_users',
#  'cast_total_facebook_likes',
#  'actor_3_name',
#  'facenumber_in_poster',
#  'plot_keywords',
#  'movie_imdb_link',
#  'num_user_for_reviews',
#  'language',
#  'country',
#  'content_rating',
#  'budget',
#  'title_year',
#  'actor_2_facebook_likes',
#  'imdb_score',
#  'aspect_ratio',
#  'movie_facebook_likes']

# %% [markdown]
# <h1>Realizando a Análise Exploratória</h1>

# %%
#removendo a coluna com o link do filme no IMDB
df.drop('movie_imdb_link', axis=1, inplace=True)

# %%
#verificando os valores presentes na coluna Color
df['color'].value_counts()
# Out:
# Color               4815
#  Black and White     209
# Name: color, dtype: int64

# %%
#removendo a coluna color (não é relevante para a análise)
df.drop('color', axis=1, inplace=True)

# %%
#verificando as colunas com dados faltantes 
df.isna().any()
# Out:
# director_name                 True
# num_critic_for_reviews        True
# duration                      True
# director_facebook_likes       True
# actor_3_facebook_likes        True
# actor_2_name                  True
# actor_1_facebook_likes        True
# gross                         True
# genres                       False
# actor_1_name                  True
# movie_title                  False
# num_voted_users              False
# cast_total_facebook_likes    False
# actor_3_name                  True
# facenumber_in_poster          True
# plot_keywords                 True
# num_user_for_reviews          True
# language                      True
# country                       True
# content_rating                True
# budget                        True
# title_year                    True
# actor_2_facebook_likes        True
# imdb_score                   False
# aspect_ratio                  True
# movie_facebook_likes         False
# dtype: bool

# %%
#verificando o número de dados faltantes em cada coluna
df.isna().sum()
# Out:
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
#removendo linhas com poucos dados faltantes
df.dropna(axis=0, subset=['director_name', 'num_critic_for_reviews', 'duration', 'director_facebook_likes',
                          'actor_3_facebook_likes', 'actor_2_name', 'actor_1_facebook_likes', 'actor_1_name', 'actor_3_name', 
                          'actor_2_name', 'actor_1_facebook_likes', 'actor_1_name', 'actor_3_name', 'facenumber_in_poster',
                          'num_user_for_reviews', 'language', 'country', 'actor_2_facebook_likes', 'plot_keywords', 
                          'title_year'], inplace=True)

# %%
#verificando como ficou o tamanho do dataframe (pequena perda)
df.shape
# Out:
# (4737, 26)

# %%
#verificando valores existentes na coluna content rating
df['content_rating'].value_counts()
# Out:
# R            2082
# PG-13        1436
# PG            681
# G             109
# Not Rated     100
# Unrated        58
# Approved       55
# X              13
# Passed          9
# NC-17           7
# GP              6
# M               5
# TV-G            3
# TV-14           3
# TV-PG           1
# Name: content_rating, dtype: int64

# %%
#substituindo valores faltantes por R
df['content_rating'].fillna('R', inplace=True)

# %%
#verificando valores existentes na coluna aspect ratio
df['aspect_ratio'].value_counts()
# Out:
# 2.35     2311
# 1.85     1884
# 1.37       97
# 1.78       80
# 1.66       63
# 1.33       34
# 2.20       15
# 2.39       14
# 16.00       8
# 2.00        4
# 1.75        3
# 2.40        3
# 2.76        3
# 2.55        2
# 1.50        2
# 2.24        1
# 1.20        1
# 1.18        1
# 1.44        1
# 1.77        1
# Name: aspect_ratio, dtype: int64

# %%
#substituindo valores faltantes pela mediana dos valores
df['aspect_ratio'].fillna(df['aspect_ratio'].median(), inplace=True)

# %%
#substituindo valores faltantes pela mediana dos valores
df['budget'].fillna(df['budget'].median(), inplace=True)

# %%
#substituindo valores faltantes pela mediana dos valores
df['gross'].fillna(df['budget'].median(), inplace=True)

# %%
#verificando se todos valores faltantes foram substituidos ou removidos
df.isna().sum()
# Out:
# director_name                0
# num_critic_for_reviews       0
# duration                     0
# director_facebook_likes      0
# actor_3_facebook_likes       0
# actor_2_name                 0
# actor_1_facebook_likes       0
# gross                        0
# genres                       0
# actor_1_name                 0
# movie_title                  0
# num_voted_users              0
# cast_total_facebook_likes    0
# actor_3_name                 0
# facenumber_in_poster         0
# plot_keywords                0
# num_user_for_reviews         0
# language                     0
# country                      0
# content_rating               0
# budget                       0
# title_year                   0
# actor_2_facebook_likes       0
# imdb_score                   0
# aspect_ratio                 0
# movie_facebook_likes         0
# dtype: int64

# %%
#verificando existência de dados duplicados
df.duplicated().sum()
# Out:
# 42

# %%
#removendo os dados duplicados
df.drop_duplicates(inplace=True)

# %%
#verificando tamanho do dataframe
df.shape
# Out:
# (4695, 26)

# %%
#verificando valores existentes na coluna language
df['language'].value_counts()
# Out:
# English       4405
# French          69
# Spanish         35
# Hindi           25
# Mandarin        24
# German          18
# Japanese        16
# Russian         11
# Cantonese       10
# Italian         10
# Portuguese       8
# Korean           8
# Danish           5
# Dutch            4
# Persian          4
# Hebrew           4
# Norwegian        4
# Swedish          4
# Arabic           3
# Thai             3
# Indonesian       2
# Dari             2
# Aboriginal       2
# Zulu             2
# None             2
# Mongolian        1
# Maya             1
# Aramaic          1
# Dzongkha         1
# Vietnamese       1
# Kazakh           1
# Filipino         1
# Bosnian          1
# Czech            1
# Polish           1
# Telugu           1
# Icelandic        1
# Hungarian        1
# Greek            1
# Romanian         1
# Name: language, dtype: int64

# %%
#removendo coluna language (dados não relevantes)
df.drop('language', axis=1, inplace=True)

# %%
#verificando dados existentes na coluna country
df['country'].value_counts()
# Out:
# USA               3568
# UK                 420
# France             149
# Canada             107
# Germany             96
# Australia           53
# Spain               32
# India               27
# China               24
# Japan               21
# Italy               20
# Hong Kong           16
# New Zealand         14
# South Korea         12
# Ireland             11
# Denmark             11
# Russia              11
# Mexico              11
# South Africa         8
# Brazil               8
# Norway               7
# Sweden               5
# Netherlands          5
# Thailand             4
# Argentina            4
# Iran                 4
# Czech Republic       3
# West Germany         3
# Belgium              3
# Switzerland          3
# Israel               3
# Taiwan               2
# Hungary              2
# Greece               2
# Romania              2
# Iceland              2
# Poland               2
# Slovakia             1
# Cambodia             1
# Philippines          1
# ...

# %%
#removendo coluna country (dados não relevantes)
df.drop('country', axis=1, inplace=True)

# %%
#criando uma coluna Profit
df['Profit'] = df['budget'].sub(df['gross'], axis=0)

# %%
#verificando se foi criada corretamente
df.head()
# Out:
#        director_name  num_critic_for_reviews  duration  \
# 0      James Cameron                   723.0     178.0
# 1     Gore Verbinski                   302.0     169.0
# 2         Sam Mendes                   602.0     148.0
# 3  Christopher Nolan                   813.0     164.0
# 5     Andrew Stanton                   462.0     132.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 5                    475.0                   530.0   Samantha Morton
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
#criando coluna Profit Percentage
df['Profit_Percentage'] = (df['Profit']/df['gross'])*100

# %%
#verificando criação da coluna
df.head()
# Out:
#        director_name  num_critic_for_reviews  duration  \
# 0      James Cameron                   723.0     178.0
# 1     Gore Verbinski                   302.0     169.0
# 2         Sam Mendes                   602.0     148.0
# 3  Christopher Nolan                   813.0     164.0
# 5     Andrew Stanton                   462.0     132.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 5                    475.0                   530.0   Samantha Morton
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
#salvando os dados do dataframe em um arquivo csv
df.to_csv('dados_imdb_analiseexpl.csv', index=False)

# %% [markdown]
# <h1>Visualização dos dados</h1>

# %%
#criando um gráfico que correlaciona lucro e a nota do IMDB
ggplot(aes(x='imdb_score', y='Profit'), data=df) +\
      geom_line() +\
stat_smooth(color='blue', span=1)
# Out:
# <ggplot: (107805217657)>

# %%
#criando um gráfico que correlaciona likes no Facebook e nota do IMDB
ggplot(df)+\
aes(x='imdb_score', y='movie_facebook_likes') +\
geom_line() +\
labs(title='Nota no IMDB vs Likes no Facebook do Filme', x='Nota no IMDB', y='Likes no Facebook')
# Out:
# <ggplot: (107804596432)>

# %%
#criando um gráfico dos 20 filmes com a melhor nota em relação aos atores principais
plt.figure(figsize=(10,8))

df= df.sort_values(by ='imdb_score', ascending=False)
df2=df.head(20)
ax=sns.pointplot(df2['actor_1_name'],df2['imdb_score'], hue=df2['movie_title'])
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# <h1>Preparando os dados</h1>

# %%
#removendo algumas colunas com dados categóricos
df.drop(columns=['director_name', 'actor_1_name', 'actor_2_name', 'actor_3_name', 'plot_keywords', 
                 'movie_title'], axis=1, inplace=True)

# %%
#verificando valores existentes na coluna genres
df['genres'].value_counts()
# Out:
# Drama                              209
# Comedy                             186
# Comedy|Drama|Romance               182
# Comedy|Drama                       180
# Comedy|Romance                     149
#                                   ...
# Drama|History|War|Western            1
# Action|Drama|Romance|Sport           1
# Adventure|Horror|Mystery             1
# Action|Adventure|Fantasy|Horror      1
# Biography|Crime|Drama|Music          1
# Name: genres, Length: 875, dtype: int64

# %%
#removendo a coluna genres
df.drop('genres', axis=1, inplace=True)

# %%
#removendo colunas criadas
df.drop(columns=['Profit', 'Profit_Percentage'], axis=1, inplace=True)

# %%
#verificando existência de colunas fortemente correlacionadas (Mapa de Calor)
import numpy as np
corr = df.corr()
sns.set_context("notebook", font_scale=1.0, rc={"lines.linewidth": 2.5})
plt.figure(figsize=(13,7))
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask, 1)] = True
a = sns.heatmap(corr,mask=mask, annot=True, fmt='.2f')
rotx = a.set_xticklabels(a.get_xticklabels(), rotation=90)
roty = a.set_yticklabels(a.get_yticklabels(), rotation=30)

# %%
#criando coluna Other actors facebook likes (combinação de colunas fortemente relacionadas)
df['Other_actors_facebook_likes'] = df['actor_2_facebook_likes'] + df['actor_3_facebook_likes']

# %%
#removendo colunas unidas anteriormente
df.drop(columns=['actor_2_facebook_likes', 'actor_3_facebook_likes', 'cast_total_facebook_likes'], axis=1, inplace=True)

# %%
#criando coluna critic review ratio (combinação de colunas fortemente relacionadas)
df['critic_review_ratio'] = df['num_critic_for_reviews']/df['num_user_for_reviews']

# %%
#removendo colunas
df.drop(columns=['num_critic_for_reviews', 'num_user_for_reviews'], axis=1, inplace=True)

# %%
#verificando existência colunas fortemente correlacionadas
corr = df.corr()
sns.set_context("notebook", font_scale=1.0, rc={"lines.linewidth": 2.5})
plt.figure(figsize=(13,7))
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask, 1)] = True
a = sns.heatmap(corr,mask=mask, annot=True, fmt='.2f')
rotx = a.set_xticklabels(a.get_xticklabels(), rotation=90)
roty = a.set_yticklabels(a.get_yticklabels(), rotation=30)

# %%
#categorizando os valores de nota do imdb
df['imdb_binned_score']=pd.cut(df['imdb_score'], bins=[0,4,6,8,10], right=True, labels=False)+1

# %%
df.head()
# Out:
#       duration  director_facebook_likes  actor_1_facebook_likes        gross  \
# 1937     142.0                      0.0                 11000.0   28341469.0
# 3466     175.0                      0.0                 14000.0  134821952.0
# 2837     220.0                      0.0                 22000.0   57300000.0
# 66       152.0                  22000.0                 23000.0  533316061.0
# 4822      96.0                      0.0                   359.0   20000000.0
#
#       num_voted_users  facenumber_in_poster content_rating       budget  \
# 1937          1689764                   0.0              R   25000000.0
# 3466          1155770                   1.0              R    6000000.0
# 2837           790926                   1.0              R   13000000.0
# 66            1676169                   0.0          PG-13  185000000.0
# 4822           447785                   1.0      Not Rated     350000.0
#
#       title_year  imdb_score  aspect_ratio  movie_facebook_likes  \
# ...

# %%
#criando novas colunas para transformar os valores categóricos de content rating em valores numéricos
df = pd.get_dummies(data = df, columns=['content_rating'], prefix=['content_rating'], drop_first=True)

# %%
df.head()
# Out:
#       duration  director_facebook_likes  actor_1_facebook_likes        gross  \
# 1937     142.0                      0.0                 11000.0   28341469.0
# 3466     175.0                      0.0                 14000.0  134821952.0
# 2837     220.0                      0.0                 22000.0   57300000.0
# 66       152.0                  22000.0                 23000.0  533316061.0
# 4822      96.0                      0.0                   359.0   20000000.0
#
#       num_voted_users  facenumber_in_poster       budget  title_year  \
# 1937          1689764                   0.0   25000000.0      1994.0
# 3466          1155770                   1.0    6000000.0      1972.0
# 2837           790926                   1.0   13000000.0      1974.0
# 66            1676169                   0.0  185000000.0      2008.0
# 4822           447785                   1.0     350000.0      1957.0
#
#       imdb_score  aspect_ratio  ...  content_rating_Not Rated  \
# ...

# %%
#salvando em arquivo csv
df.to_csv('dados_imdb_com_nota.csv', index=False)

# %%
#escolhendo as colunas do dataframe que serão os valores de entrada para o modelo
X=pd.DataFrame(columns=['duration', 'director_facebook_likes', 'actor_1_facebook_likes', 'gross', 'num_voted_users', 
                        'facenumber_in_poster', 'budget', 'title_year', 'aspect_ratio', 'movie_facebook_likes', 
                        'Other_actors_facebook_likes', 'critic_review_ratio', 'content_rating_G', 'content_rating_GP', 
                        'content_rating_M', 'content_rating_NC-17', 'content_rating_Not Rated', 'content_rating_PG',
                        'content_rating_PG-13', 'content_rating_Passed', 'content_rating_R', 'content_rating_TV-14',
                        'content_rating_TV-G', 'content_rating_TV-PG', 'content_rating_Unrated', 'content_rating_X'],data=df)

# %%
#escolhendo a coluna do dataframe que servira de resposta ao modelo
y = pd.DataFrame(columns=['imdb_binned_score'], data=df)

# %%
#importando o pacote de divisão dos dados em treinamento e teste
from sklearn.model_selection import train_test_split

# %%
#dividindo os dados em treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
#normalizando os dados
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)

# %%
X.isna().sum()
# Out:
# duration                       0
# director_facebook_likes        0
# actor_1_facebook_likes         0
# gross                          0
# num_voted_users                0
# facenumber_in_poster           0
# budget                         0
# title_year                     0
# aspect_ratio                   0
# movie_facebook_likes           0
# Other_actors_facebook_likes    0
# critic_review_ratio            0
# content_rating_G               0
# content_rating_GP              0
# content_rating_M               0
# content_rating_NC-17           0
# content_rating_Not Rated       0
# content_rating_PG              0
# content_rating_PG-13           0
# content_rating_Passed          0
# content_rating_R               0
# content_rating_TV-14           0
# content_rating_TV-G            0
# content_rating_TV-PG           0
# content_rating_Unrated         0
# content_rating_X               0
# dtype: int64

# %%
#importando, configurando e treinando o modelo de regressão 
from sklearn.linear_model import LogisticRegression
logit = LogisticRegression(verbose=1, max_iter=1000)
logit.fit(X_train,np.ravel(y_train, order='C'))
y_pred=logit.predict(X_test)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s finished

# %%
#verificando os valores preditos
y_pred
# Out:
# array([3, 3, 3, ..., 2, 3, 3], dtype=int64)

# %%
#importando o pacote de métricas e calculando a matriz de confusão
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)

# %%
#código para melhor visualização da matriz de confusão
#alternativa:  print(cnf_matrix)
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
#imprimindo a matriz de confusão
plot_confusion_matrix(cnf_matrix, classes=['1', '2', '3', '4'], title='Matriz de confusão não normalizada', normalize=False)

# %%
#verificando valores existentes na coluna imdb binned score
df['imdb_binned_score'].value_counts()
# Out:
# 3    3015
# 2    1323
# 4     203
# 1     154
# Name: imdb_binned_score, dtype: int64

# %%
#imprimindo as métricas finais
print(metrics.classification_report(y_test, y_pred, target_names=['1', '2', '3', '4']))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        45
#            2       0.55      0.41      0.47       392
#            3       0.74      0.87      0.80       904
#            4       0.80      0.54      0.65        68
#
#     accuracy                           0.70      1409
#    macro avg       0.52      0.46      0.48      1409
# weighted avg       0.66      0.70      0.67      1409

# %%
#importante o pacote para salvar o modelo
import pickle

# %%
#definindo o caminho para salvar o modelo
modelo_treinado = 'modelo_imdb.sav'

# %%
#salvando o modelo
pickle.dump(logit, open(modelo_treinado, 'wb'))

# %%
#carregando o modelo treinado
modelo_carregado = pickle.load(open(modelo_treinado, 'rb'))

# %%
#Olhando o conteúdo de um vetor de teste
X_test[0]
# Out:
# array([-0.11125319,  0.12234245, -0.47077098, -0.55187155,  0.102644  ,
#        -0.18064455, -0.29363035,  0.56016395, -0.41895874,  0.10788607,
#        -0.40176212,  0.17842293, -0.14967295, -0.04276995, -0.03491087,
#        -0.04276995, -0.14093771, -0.41056461, -0.65997074, -0.03903749,
#         1.05121875, -0.0302291 , -0.0302291 , -0.01744746, -0.11240473,
#        -0.05240624])

# %%
#realizando a predição do novo dado com o modelo carregado
modelo_carregado.predict([X_test[0]])
# Out:
# array([3], dtype=int64)
